# %% [markdown]
# <a href="https://colab.research.google.com/github/KEANU2003/Google-s-First-Webpage/blob/main/Deepseek_R1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geoopt
# Out:
# Collecting geoopt
#   Downloading geoopt-0.5.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from geoopt) (2.5.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from geoopt) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from geoopt) (1.13.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->geoopt) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->geoopt) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->geoopt) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->geoopt) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->geoopt) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->geoopt) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->geoopt) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->geoopt) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->geoopt) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->geoopt) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->geoopt) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->geoopt) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->geoopt) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->geoopt) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->geoopt) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->geoopt) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->geoopt) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->geoopt) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.9.0->geoopt) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.9.0->geoopt) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.9.0->geoopt) (3.0.2)
# Downloading geoopt-0.5.0-py3-none-any.whl (90 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.1/90.1 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: geoopt
# Successfully installed geoopt-0.5.0

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from transformers import AutoTokenizer
from geoopt import PoincareBall
from geoopt.optim import RiemannianAdam
import random

# =============================================================================
#                            MODEL DEFINITION
# =============================================================================
class SmallRLModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(SmallRLModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, output_dim)
        self.manifold = PoincareBall(c=1.0)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.manifold.expmap0(x)  # Map to hyperbolic space
        x = self.fc2(self.manifold.logmap0(x))  # Back to Euclidean space
        return x

class SmallerRLModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(SmallerRLModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# =============================================================================
#                            REWARD FUNCTIONS
# =============================================================================
def compute_accuracy_reward(output, target):
    """Reward based on cosine similarity between output and target embeddings."""
    cos_sim = F.cosine_similarity(output, target, dim=-1)
    return cos_sim.mean().item()

def compute_format_reward(response, required_format):
    """Reward for adhering to the required format."""
    if required_format in response:
        return 1.0
    return -1.0

def compute_combined_reward(output, target, response, required_format):
    """Combine accuracy and format rewards."""
    accuracy_reward = compute_accuracy_reward(output, target)
    format_reward = compute_format_reward(response, required_format)
    return accuracy_reward + format_reward

# =============================================================================
#                            TRAINING FUNCTION
# =============================================================================
def train_with_rl(
    model,
    optimizer,
    dataset,
    input_dim,
    output_dim,
    epochs=5,
    max_seq_len=50
):
    history = []

    for epoch in range(epochs):
        print(f"Epoch {epoch + 1}/{epochs}")
        for sample in dataset:
            # Extract prompt and target embedding (dummy data here for simplicity)
            prompt = sample["Prompt"]
            target_text = sample["Target"]

            # Convert text to embeddings (random here for demo purposes)
            input_embedding = torch.rand((1, max_seq_len, input_dim)).to(device)
            target_embedding = torch.rand((1, max_seq_len, output_dim)).to(device)

            optimizer.zero_grad()

            # Forward pass
            output_embedding = model(input_embedding)

            # Decode output embedding to simulate model response
            model_response = "<think> Simulated response </think>"  # Simulated decoding for demo purposes

            # Compute rewards
            required_format = "<think>"
            combined_reward = compute_combined_reward(
                output_embedding, target_embedding, model_response, required_format
            )

            # Loss = negative reward (maximize reward)
            loss = -torch.tensor(combined_reward, requires_grad=True).to(device)

            loss.backward()
            optimizer.step()

            history.append({
                "epoch": epoch + 1,
                "prompt": prompt,
                "reward": combined_reward,
                "loss": loss.item(),
                "response": model_response
            })

            print(f"Prompt: {prompt[:30]}... | Response: {model_response} | Combined Reward: {combined_reward:.4f} | Loss: {loss.item():.4f}")

    return history

# =============================================================================
#                      DISTILLATION FUNCTION
# =============================================================================
def distill_model(teacher_model, student_model, dataset, optimizer, epochs=5, max_seq_len=50):
    """Distill knowledge from the teacher model to the smaller student model."""
    for epoch in range(epochs):
        print(f"Distillation Epoch {epoch + 1}/{epochs}")
        for sample in dataset:
            # Extract prompt (dummy data here for simplicity)
            prompt = sample["Prompt"]

            # Convert text to embeddings (random here for demo purposes)
            input_embedding = torch.rand((1, max_seq_len, input_dim)).to(device)

            # Teacher model output
            with torch.no_grad():
                teacher_output = teacher_model(input_embedding)

            # Student model output
            student_output = student_model(input_embedding)

            # Loss = MSE between teacher and student outputs
            loss = F.mse_loss(student_output, teacher_output)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            print(f"Prompt: {prompt[:30]}... | Distillation Loss: {loss.item():.4f}")

# =============================================================================
#                            MAIN EXECUTION
# =============================================================================
if __name__ == "__main__":
    # ---------------------------
    # 1) Device Setup
    # ---------------------------
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # ---------------------------
    # 2) Model and Optimizer Setup
    # ---------------------------
    input_dim = 128  # Example input dimension
    hidden_dim = 256  # Hidden layer dimension
    output_dim = 128  # Output dimension matches input for reconstruction

    model = SmallRLModel(input_dim, hidden_dim, output_dim).to(device)
    optimizer = RiemannianAdam(model.parameters(), lr=1e-4)

    # ---------------------------
    # 3) Dataset (Dummy Data)
    # ---------------------------
    # Replace with actual reasoning task data
    dataset = [
        {"Prompt": "Solve x + 2 = 5.", "Target": "x = 3."},
        {"Prompt": "What is the capital of France?", "Target": "Paris."},
        {"Prompt": "Explain Pythagoras' theorem.", "Target": "a^2 + b^2 = c^2 for a right triangle."}
    ]

    # ---------------------------
    # 4) Training
    # ---------------------------
    history = train_with_rl(
        model=model,
        optimizer=optimizer,
        dataset=dataset,
        input_dim=input_dim,
        output_dim=output_dim,
        epochs=10,
        max_seq_len=50
    )

    print("Training complete.")

    # ---------------------------
    # 5) Distillation
    # ---------------------------
    smaller_model = SmallerRLModel(input_dim, hidden_dim // 2, output_dim).to(device)
    distill_optimizer = torch.optim.Adam(smaller_model.parameters(), lr=1e-4)

    distill_model(
        teacher_model=model,
        student_model=smaller_model,
        dataset=dataset,
        optimizer=distill_optimizer,
        epochs=5,
        max_seq_len=50
    )

    print("Distillation complete.")
# Out:
# Epoch 1/10
# Prompt: Solve x + 2 = 5.... | Response: <think> Simulated response </think> | Combined Reward: 0.9505 | Loss: -0.9505
# Prompt: What is the capital of France?... | Response: <think> Simulated response </think> | Combined Reward: 0.9288 | Loss: -0.9288
# Prompt: Explain Pythagoras' theorem.... | Response: <think> Simulated response </think> | Combined Reward: 0.9269 | Loss: -0.9269
# Epoch 2/10
# Prompt: Solve x + 2 = 5.... | Response: <think> Simulated response </think> | Combined Reward: 0.9438 | Loss: -0.9438
# Prompt: What is the capital of France?... | Response: <think> Simulated response </think> | Combined Reward: 0.9157 | Loss: -0.9157
# Prompt: Explain Pythagoras' theorem.... | Response: <think> Simulated response </think> | Combined Reward: 0.9445 | Loss: -0.9445
# Epoch 3/10
# Prompt: Solve x + 2 = 5.... | Response: <think> Simulated response </think> | Combined Reward: 0.9322 | Loss: -0.9322
# Prompt: What is the capital of France?... | Response: <think> Simulated response </think> | Combined Reward: 0.9263 | Loss: -0.9263
# Prompt: Explain Pythagoras' theorem.... | Response: <think> Simulated response </think> | Combined Reward: 0.9463 | Loss: -0.9463
# Epoch 4/10
# Prompt: Solve x + 2 = 5.... | Response: <think> Simulated response </think> | Combined Reward: 0.9354 | Loss: -0.9354
# Prompt: What is the capital of France?... | Response: <think> Simulated response </think> | Combined Reward: 0.9420 | Loss: -0.9420
# Prompt: Explain Pythagoras' theorem.... | Response: <think> Simulated response </think> | Combined Reward: 0.9583 | Loss: -0.9583
# Epoch 5/10
# Prompt: Solve x + 2 = 5.... | Response: <think> Simulated response </think> | Combined Reward: 0.9357 | Loss: -0.9357
# Prompt: What is the capital of France?... | Response: <think> Simulated response </think> | Combined Reward: 0.9494 | Loss: -0.9494
# Prompt: Explain Pythagoras' theorem.... | Response: <think> Simulated response </think> | Combined Reward: 0.9269 | Loss: -0.9269
# Epoch 6/10
# Prompt: Solve x + 2 = 5.... | Response: <think> Simulated response </think> | Combined Reward: 0.9354 | Loss: -0.9354
# Prompt: What is the capital of France?... | Response: <think> Simulated response </think> | Combined Reward: 0.9189 | Loss: -0.9189
# Prompt: Explain Pythagoras' theorem.... | Response: <think> Simulated response </think> | Combined Reward: 0.9353 | Loss: -0.9353
# Epoch 7/10
# Prompt: Solve x + 2 = 5.... | Response: <think> Simulated response </think> | Combined Reward: 0.9435 | Loss: -0.9435
# Prompt: What is the capital of France?... | Response: <think> Simulated response </think> | Combined Reward: 0.9394 | Loss: -0.9394
# Prompt: Explain Pythagoras' theorem.... | Response: <think> Simulated response </think> | Combined Reward: 0.9303 | Loss: -0.9303
# Epoch 8/10
# Prompt: Solve x + 2 = 5.... | Response: <think> Simulated response </think> | Combined Reward: 0.9433 | Loss: -0.9433
# Prompt: What is the capital of France?... | Response: <think> Simulated response </think> | Combined Reward: 0.9377 | Loss: -0.9377
# Prompt: Explain Pythagoras' theorem.... | Response: <think> Simulated response </think> | Combined Reward: 0.9385 | Loss: -0.9385
# Epoch 9/10
# Prompt: Solve x + 2 = 5.... | Response: <think> Simulated response </think> | Combined Reward: 0.9429 | Loss: -0.9429
# Prompt: What is the capital of France?... | Response: <think> Simulated response </think> | Combined Reward: 0.9351 | Loss: -0.9351
# Prompt: Explain Pythagoras' theorem.... | Response: <think> Simulated response </think> | Combined Reward: 0.9295 | Loss: -0.9295
# Epoch 10/10
# Prompt: Solve x + 2 = 5.... | Response: <think> Simulated response </think> | Combined Reward: 0.9484 | Loss: -0.9484
# Prompt: What is the capital of France?... | Response: <think> Simulated response </think> | Combined Reward: 0.9584 | Loss: -0.9584
# Prompt: Explain Pythagoras' theorem.... | Response: <think> Simulated response </think> | Combined Reward: 0.9333 | Loss: -0.9333
# Training complete.
# Distillation Epoch 1/5
# Prompt: Solve x + 2 = 5.... | Distillation Loss: 0.0346
# Prompt: What is the capital of France?... | Distillation Loss: 0.0329
# Prompt: Explain Pythagoras' theorem.... | Distillation Loss: 0.0323
# Distillation Epoch 2/5
# Prompt: Solve x + 2 = 5.... | Distillation Loss: 0.0304
# Prompt: What is the capital of France?... | Distillation Loss: 0.0293
# Prompt: Explain Pythagoras' theorem.... | Distillation Loss: 0.0297
# Distillation Epoch 3/5
# Prompt: Solve x + 2 = 5.... | Distillation Loss: 0.0280
# Prompt: What is the capital of France?... | Distillation Loss: 0.0279
# Prompt: Explain Pythagoras' theorem.... | Distillation Loss: 0.0266
# Distillation Epoch 4/5
# Prompt: Solve x + 2 = 5.... | Distillation Loss: 0.0251
# Prompt: What is the capital of France?... | Distillation Loss: 0.0248
# Prompt: Explain Pythagoras' theorem.... | Distillation Loss: 0.0248
# Distillation Epoch 5/5
# Prompt: Solve x + 2 = 5.... | Distillation Loss: 0.0235
# Prompt: What is the capital of France?... | Distillation Loss: 0.0228
# Prompt: Explain Pythagoras' theorem.... | Distillation Loss: 0.0223
# Distillation complete.
